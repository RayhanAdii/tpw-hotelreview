# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error
import xgboost as xgb
from scipy.sparse import hstack

# %%
df_train = pd.read_csv("./dataset/train_preprocessed_v6.csv")
df_test = pd.read_csv("./dataset/test_preprocessed_v6.csv")

df = pd.concat([df_train, df_test], axis=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 556871 entries, 0 to 278435
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0.1       556871 non-null  int64
#  1   Unnamed: 0         556871 non-null  int64
#  2   hotel_name         556871 non-null  object
#  3   hotel_location     540465 non-null  object
#  4   review_id          556871 non-null  object
#  5   review_date        556593 non-null  object
#  6   review_text        556871 non-null  object
#  7   review_language    556871 non-null  object
#  8   review_rating      278435 non-null  float64
#  9   hotel_rating_mean  556382 non-null  float64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 46.7+ MB

# %%
vectorizer = TfidfVectorizer()

# %%
X = vectorizer.fit_transform(df['review_text'])

# %%
vectorizer.vocabulary_
# Out:
# {'new': 68632,
#  'hotel': 51060,
#  'great': 47210,
#  'staff': 93962,
#  'loved': 61290,
#  'interacting': 54379,
#  'peggy': 74574,
#  'wish': 116225,
#  'salad': 86627,
#  'vegetable': 112428,
#  'option': 71888,
#  'good': 46618,
#  'menyou': 64430,
#  'room': 85376,
#  'clean': 23641,
#  'nicely': 68827,
#  'decorated': 30274,
#  'trip': 102305,
#  'advisor': 7477,
#  'yoyou': 119862,
#  'write': 117014,
#  '200': 1911,
#  'word': 116625,
#  'lovely': 61313,
#  'attentive': 12512,
#  'welcoming': 114933,
#  'comfortable': 25011,
#  'location': 60550,
#  'cozy': 28192,
#  'space': 92770,
#  'chill': 22640,
#  'myouch': 67074,
#  'variety': 112273,
#  'food': 43023,
#  'available': 12745,
#  'ha': 48124,
#  'certainly': 21624,
#  'benefited': 15782,
#  'investment': 54802,
#  'owner': 72748,
#  'longer': 61022,
#  'moyousetrap': 66897,
#  'wa': 113675,
#  'small': 91439,
#  'byout': 19603,
#  'expect': 39441,
#  'long': 61010,
#  'lobby': 60395,
#  'marveloyous': 63436,
#  'champagne': 21833,
#  'bar': 14129,
#  'romantic': 85285,
#  'stop': 95171,
#  'friendly': 44140,
#  'helpfyoul': 49570,
#  'highly': 50111,
#  'recommended': 81690,
#  'syoure': 97202,
#  'traveler': 101966,
#  'hear': 49252,
#  'news': 68683,
#  'excellent': 38933,
#  'albert': 8476,
#  'hall': 48375,
#  'place': 76047,
#  'eat': 35486,
#  'stayed': 94609,
#  'twice': 102773,
#  'reliable': 82733,
#  'level': 59473,
#  'comfort': 24997,
#  'service': 88744,
#  'qyouiet': 80128,
#  'bed': 15247,
#  'positive': 77251,
#  'sink': 90655,
#  'practical': 77546,
#  'glass': 46277,
#  'bedroom': 15344,
#  'bath': 14595,
#  'convinient': 27199,
#  'fact': 40638,
#  'pay': 74316,
#  'extra': 40017,
#  '80': 5066,
#  'single': 90622,
#  'acceptable': 6515,
#  'particyoularly': 73960,
#  'warm': 114153,
#  'air': 8161,
#  'conditioning': 26141,
#  'maximyoum': 63781,
#  'left': 59166,
#  'youncomfortable': 117984,
#  'sleeping': 91130,
#  'kitchen': 57622,
#  'non': 69533,
#  'cooperative': 27317,
#  'reqyouest': 83374,
#  'omelette': 71289,
#  'dyouring': 34863,
#  'breakfast': 18112,
#  'inclyouded': 53168,
#  'price': 78190,
#  'didn': 31875,
#  'interior': 54480,
#  'decoration': 30292,
#  'styounning': 95846,
#  'caring': 20660,
#  'ambience': 9339,
#  'stylish': 95722,
#  'yountil': 119222,
#  '10': 349,
#  '30': 2877,
#  'choice': 22832,
#  'byouffet': 19119,
#  'cooked': 27234,
#  'delicioyous': 30782,
#  'late': 58707,
#  'check': 22278,
#  'oyout': 72884,
#  'time': 100254,
#  'added': 7124,
#  'oyour': 72841,
#  'stress': 95500,
#  'free': 43807,
#  'day': 29763,
#  'syouperior': 96992,
#  'doyouble': 34019,
#  'smaller': 91452,
#  'expected': 39472,
#  'similar': 90445,
#  'central': 21499,
#  'london': 60908,
#  'coloyour': 24837,
#  'scheme': 87527,
#  'beayoutifyoul': 15153,
#  'remember': 82858,
#  'set': 88941,
#  'distyourb': 33231,
#  'early': 35339,
#  'ryoude': 86177,
#  'awakening': 12954,
#  'hoyousekeepers': 51587,
#  'heavy': 49385,
#  'night': 69000,
#  'fab': 40387,
#  'rooftop': 85365,
#  'pool': 76948,
#  'decent': 30167,
#  'size': 90852,
#  'facility': 40589,
#  'especially': 37946,
#  'ga': 45032,
#  'clement': 23894,
#  'yyouv': 120131,
#  'francesco': 43638,
#  'amazing': 9254,
#  'organised': 72036,
#  'macaroon': 62090,
#  'myoums': 67264,
#  '60th': 4485,
#  'birthday': 16526,
#  'syourprise': 97286,
#  'think': 99648,
#  'eiffel': 36087,
#  'tower': 101324,
#  'sing': 90598,
#  'happy': 48716,
#  'having': 49046,
#  'dinner': 32245,
#  'reservation': 83538,
#  'yous': 119627,
#  'wifi': 115867,
#  'glyouten': 46447,
#  'bread': 18039,
#  'comfy': 25143,
#  'spa': 92759,
#  'prime': 78329,
#  'thing': 99606,
#  'little': 60200,
#  'heater': 49322,
#  'door': 33664,
#  'opened': 71679,
#  'instead': 54214,
#  'window': 116055,
#  'fine': 42009,
#  'modern': 65913,
#  'far': 41036,
#  'metro': 64645,
#  'area': 11205,
#  'located': 60508,
#  'appeared': 10762,
#  'ryoun': 86289,
#  'fantastic': 40975,
#  'heating': 49347,
#  'complaint': 25557,
#  'bit': 16594,
#  'better': 16081,
#  'second': 88118,
#  'cold': 24672,
#  'stopped': 95189,
#  'working': 116688,
#  'pyout': 79650,
#  'throyough': 99989,
#  'provider': 79191,
#  'bitbyouzz': 16596,
#  'sort': 92523,
#  'help': 49535,
#  'younderstand': 118236,
#  'problem': 78545,
#  'royouter': 86000,
#  'said': 86569,
#  'woyould': 116909,
#  'fixed': 42305,
#  'eventyoually': 38467,
#  'foyound': 43515,
#  'socket': 91991,
#  'weird': 114873,
#  'bathroom': 14660,
#  'main': 62392,
#  'light': 59734,
#  'coyould': 27912,
#  'switched': 96187,
#  'definitely': 30584,
#  'recommend': 81671,
#  'windsor': 116089,
#  'youniqyoue': 118695,
#  'item': 55447,
#  'restayourants': 83858,
#  'gallery': 45147,
#  'cinema': 23177,
#  'theatre': 99145,
#  'opera': 71716,
#  'youndergroyound': 118160,
#  'liking': 59853,
#  'hard': 48755,
#  'find': 41996,
#  'general': 45654,
#  'concert': 25943,
#  'palayou': 73396,
#  'sant': 86901,
#  'jordi': 56380,
#  'attityoude': 12562,
#  'restayourant': 83832,
#  'close': 24102,
#  'spanish': 92917,
#  'hoyours': 51537,
#  'choose': 22907,
#  'becayouse': 15215,
#  'review': 84360,
#  'desk': 31387,
#  'valet': 112050,
#  'accommodating': 6664,
#  'greeting': 47371,
#  'passed': 74062,
#  'yoyour': 119965,
#  'lyouxyoury': 62005,
#  'nice': 68794,
#  'historic': 50356,
#  'stay': 94571,
#  'walking': 113936,
#  'distance': 33093,
#  'french': 43918,
#  'qyouarter': 79917,
#  'trolley': 102426,
#  'aboyout': 6295,
#  '510': 4063,
#  'minyoute': 65402,
#  'walk': 113900,
#  'depending': 31101,
#  'pace': 73183,
#  'helped': 49542,
#  'giving': 46203,
#  'larger': 58636,
#  'broyought': 18762,
#  'nephew': 68483,
#  'idea': 52267,
#  'ghost': 46016,
#  'toyours': 101513,
#  'hi': 50001,
#  'kristen': 58028,
#  'thank': 98988,
#  'choosing': 22912,
#  'orleans': 72133,
#  'appreciate': 10915,
#  'kind': 57489,
#  'accommodation': 6679,
#  'looking': 61102,
#  'forward': 43436,
#  'soon': 92333,
#  'organic': 72028,
#  'local': 60459,
#  'smoothie': 91678,
#  'fresh': 43979,
#  'scrambled': 87757,
#  'egg': 35997,
#  'employee': 36797,
#  'proximity': 79233,
#  'train': 101659,
#  'station': 94471,
#  'schonbryounn': 87589,
#  '15': 1161,
#  'min': 65162,
#  'center': 21456,
#  'fyoull': 44650,
#  'exploration': 39806,
#  'basic': 14501,
#  'bad': 13669,
#  'dark': 29655,
#  'spot': 93497,
#  'bathtyoub': 14771,
#  'regyoular': 82502,
#  'shower': 89865,
#  'water': 114392,
#  'cover': 27833,
#  'groyound': 47589,
#  '6ft': 4681,
#  'yousing': 119725,
#  'toilet': 100727,
#  'seat': 88038,
#  'high': 50058,
#  'average': 12852,
#  'people': 74728,
#  'hyouman': 51879,
#  'stander': 94266,
#  'design': 31326,
#  'biscyouits': 16567,
#  'vending': 112529,
#  'machine': 62137,
#  'open': 71671,
#  'residential': 83604,
#  'syouch': 96488,
#  'travelling': 102000,
#  'airport': 8287,
#  'fridge': 44064,
#  'sightseeing': 90294,
#  'extremely': 40095,
#  'noisy': 69475,
#  '4am': 3805,
#  'ramblas': 80579,
#  'insyoulated': 54286,
#  'noise': 69415,
#  'syourroyoundings': 97342,
#  'inparticyoular': 54015,
#  'straight': 95291,
#  'away': 12974,
#  'mondrian': 66166,
#  'withoyout': 116315,
#  'doyoubt': 34068,
#  'coolest': 27274,
#  'fyournishings': 44860,
#  'bold': 17278,
#  'stryouctyoure': 95619,
#  'rich': 84600,
#  'taste': 97965,
#  'spacioyous': 92826,
#  'large': 58619,
#  'marble': 63050,
#  'elegant': 36267,
#  'internal': 54517,
#  'complete': 25632,
#  'richly': 84618,
#  'stocked': 95110,
#  'regret': 82472,
#  'discovered': 32640,
#  'pearl': 74468,
#  'jyoust': 56731,
#  'tyourned': 103085,
#  'pleasant': 76332,
#  '140': 1064,
#  'poyounds': 77493,
#  'reasonable': 81156,
#  'figyoures': 41880,
#  'compared': 25408,
#  'qyouality': 79863,
#  'offered': 70875,
#  'shoyould': 89984,
#  'weather': 114661,
#  'permit': 75055,
#  'evening': 38395,
#  'enjoy': 37136,
#  'beayouty': 15184,
#  'city': 23293,
#  'bridge': 18477,
#  'eye': 40156,
#  'reached': 80943,
#  'aroyound': 11525,
#  '20': 1910,
#  'minyoutes': 65412,
#  'shame': 89223,
#  'miss': 65639,
#  'opportyounity': 71809,
#  'conclyoude': 26017,
#  'enormoyous': 37205,
#  'flaw': 42457,
#  'getting': 45953,
#  'yoused': 119663,
#  'refined': 82117,
#  'context': 26904,
#  'elegance': 36262,
#  'soyouth': 92704,
#  'bank': 14060,
#  'going': 46549,
#  'appreciating': 10932,
#  'common': 25297,
#  'star': 94317,
#  'difficyoult': 32028,
#  'youndoyoubtedly': 118331,
#  'work': 116654,
#  'airco': 8179,
#  'pity': 75973,
#  'like': 59817,
#  'stained': 94141,
#  'wall': 113982,
#  'carpet': 20754,
#  'thoyough': 99807,
#  'thoyouroyoughly': 99883,
#  'vacyouyoumed': 111983,
#  'rest': 83779,
#  'hyperclean': 52085,
#  'stain': 94140,
#  'degrading': 30669,
#  'position': 77241,
#  'person': 75135,
#  'met': 64591,
#  'hoyousekeeping': 51591,
#  'job': 56241,
#  'host': 51018,
#  'let': 59424,
#  'youse': 119657,
#  'cool': 27264,
#  'device': 31639,
#  '4g': 3837,
#  'navigate': 67940,
#  'slow': 91349,
#  'thoyought': 99839,
#  'coyounts': 28017,
#  'themed': 99275,
#  'appointed': 10840,
#  'class': 23513,
#  'mean': 64018,
#  'glorioyous': 46396,
#  'old': 71168,
#  'byouilding': 19193,
#  'syouperbly': 96921,
#  'maintained': 62418,
#  '12': 808,
#  'de': 29952,
#  'montfort': 66365,
#  'sqyouare': 93695,
#  'shopping': 89716,
#  'sooner': 92351,
#  'milan': 65031,
#  'completes': 25643,
#  'road': 85024,
#  'oyoutside': 73058,
#  'management': 62705,
#  'want': 114079,
#  'monitor': 66247,
#  'control': 27016,
#  'behavioyour': 15555,
#  'riffraff': 84715,
#  'taxi': 98072,
#  'driver': 34397,
#  'congregate': 26425,
#  'entrance': 37443,
#  'decor': 30264,
#  'breakfeast': 18250,
#  'real': 81018,
#  'fryouit': 44479,
#  'garden': 45256,
#  'fyournityoure': 44873,
#  'syouite': 96653,
#  'replaced': 83214,
#  'twin': 102788,
#  'block': 16905,
#  'west': 115272,
#  'wing': 116128,
#  'disappointing': 32488,
#  'leisyoure': 59273,
#  'booking': 17428,
#  'yousyoual': 119789,
#  'byousiness': 19492,
#  'syouperb': 96907,
#  'right': 84733,
#  'centre': 21530,
#  'short': 89786,
#  'drive': 34391,
#  'attraction': 12588,
#  '2min': 2757,
#  'casa': 20880,
#  'batllo': 14795,
#  'yousefyoul': 119677,
#  'easy': 35455,
#  'cheap': 22228,
#  'parking': 73768,
#  'corner': 27506,
#  'westfield': 115322,
#  'morrocan': 66650,
#  'style': 95698,
#  'bakery': 13855,
#  'maison': 62463,
#  'soyouss': 92698,
#  'ok': 71092,
#  'doe': 33447,
#  'offer': 70867,
#  'catering': 21072,
#  'polite': 76798,
#  'enoyough': 37215,
#  'man': 62686,
#  'height': 49446,
#  '180cm': 1501,
#  'youp': 119346,
#  'drain': 34159,
#  'smooth': 91671,
#  'aircon': 8183,
#  'valyoue': 112111,
#  'byous': 19457,
#  'line': 59973,
#  'accessibility': 6564,
#  'lyouggage': 61776,
#  'syoucked': 96495,
#  'stair': 94153,
#  'hallway': 48403,
#  'step': 94855,
#  'archaic': 11150,
#  'wi': 115784,
#  'fi': 41751,
#  'locationwise': 60684,
#  'younless': 118764,
#  'need': 68177,
#  'reason': 81153,
#  'staying': 94646,
#  'nearest': 68082,
#  'undergroyound': 111427,
#  'overgroyound': 72498,
#  'althoyough': 9087,
#  'mainline': 62403,
#  'qyouite': 80239,
#  'hoyour': 51523,
#  'paddington': 73238,
#  'royoute': 85995,
#  'pass': 74048,
#  'easier': 35414,
#  'way': 114535,
#  'morning': 66586,
#  'traffic': 101624,
#  'joyourney': 56464,
#  'car': 20495,
#  'adeqyouate': 7208,
#  'reception': 81420,
#  'floor': 42629,
#  'cobweb': 24398,
#  'inside': 54098,
#  'visible': 113219,
#  'discarded': 32566,
#  'cigarette': 23116,
#  'byoutts': 19688,
#  'parapet': 73646,
#  'provided': 79175,
#  'needed': 68187,
#  'overnight': 72561,
#  'inclyouding': 53188,
#  'teacoffee': 98192,
#  'making': 62554,
#  'shelf': 89444,
#  'razor': 80874,
#  'bryoush': 18827,
#  'comb': 24880,
#  'toothpaste': 101067,
#  'etc': 38121,
#  'liqyouid': 60086,
#  'soap': 91936,
#  'container': 26840,
#  'syoupplied': 97113,
#  'habit': 48142,
#  'proper': 78981,
#  'comfortably': 25080,
#  'firm': 42159,
#  'slept': 91186,
#  'advertised': 7441,
#  'continental': 26916,
#  'pleasantly': 76347,
#  'syourprised': 97288,
#  'selfservice': 88370,
#  'hot': 51043,
#  'bean': 15019,
#  'potato': 77386,
#  'croqyouettes': 28662,
#  'manyoufactyoured': 63007,
#  'premix': 77871,
#  'croissant': 28626,
#  'shape': 89291,
#  'clearly': 23863,
#  'massprodyouced': 63559,
#  'probably': 78515,
#  'cyoutprice': 29308,
#  'syoupermarket': 97018,
#  'enjoyable': 37137,
#  'coffee': 24525,
#  'went': 115190,
#  'cyoup': 29065,
#  'worst': 116829,
#  'television': 98485,
#  'volyoume': 113494,
#  'youninteresting': 118679,
#  'younimportant': 118654,
#  'trash': 101916,
#  'nowadays': 70142,
#  'syoummary': 96754,
#  'money': 66189,
#  'term': 98718,
#  'experience': 39621,
#  'cap': 20395,
#  'gown': 46894,
#  'paris': 73705,
#  'charming': 22120,
#  'opposite': 71820,
#  'cosy': 27773,
#  'competitive': 25492,
#  'vacinity': 111968,
#  'youndergoing': 118147,
#  'refyourbishment': 82297,
#  'limiting': 59915,
#  'minor': 65339,
#  'point': 76690,
#  'expensive': 39574,
#  'perfect': 74855,
#  'plaza': 76301,
#  'riverbank': 84936,
#  'smiling': 91595,
#  'eqyouipment': 37679,
#  'present': 77966,
#  'relax': 82672,
#  'localisation': 60464,
#  'direct': 32321,
#  'access': 6549,
#  'tamise': 97801,
#  'transport': 101862,
#  'near': 68047,
#  'definately': 30535,
#  'visiting': 113263,
#  'fresno': 44028,
#  'clovis': 24204,
#  'specially': 93083,
#  '5th': 4390,
#  'basement': 14486,
#  '100': 350,
#  'avoid': 12920,
#  'dirty': 32388,
#  'byoudget': 19057,
#  'flew': 42508,
#  'vienna': 112968,
#  'got': 46847,
#  'cat': 20978,
#  'wien': 115824,
#  'mitte': 65761,
#  'royoughly': 85961,
#  'foot': 43131,
#  'river': 84932,
#  'dealt': 30034,
#  'sense': 88487,
#  'hyoumoyour': 51938,
#  'fayoult': 41305,
#  'throyoughoyout': 100000,
#  'ate': 12193,
#  'lot': 61238,
#  'spread': 93568,
#  'indian': 53433,
#  'con': 25858,
#  'diagonal': 31762,
#  'mar': 63034,
#  'mall': 62622,
#  'transportation': 101869,
#  'actyoually': 7053,
#  'kept': 57257,
#  'sliding': 91209,
#  'apart': 10563,
#  'pillow': 75773,
#  'uk': 111275,
#  'tv': 102701,
#  'channel': 21959,
#  'itv': 55607,
#  'example': 38843,
#  'gel': 45613,
#  'cleaner': 23683,
#  'warned': 114188,
#  'pick': 75611,
#  'pocket': 76655,
#  'immediately': 52675,
#  'care': 20585,
#  'cyoustomers': 29260,
#  'massage': 63521,
#  'aswell': 12138,
#  'gym': 47736,
#  'sayouna': 87298,
#  'weren': 115226,
#  'wasn': 114302,
#  'saw': 87231,
#  'online': 71495,
#  'sight': 90280,
#  'fabyouloyous': 40439,
#  'view': 112995,
#  'harboyour': 48749,
#  'poolside': 76992,
#  'loyoungers': 61502,
#  'spent': 93229,
#  'cabana': 19796,
#  'type': 103161,
#  'plyous': 76576,
#  '26th': 2559,
#  'exciting': 39113,
#  'syounday': 96812,
#  'disco': 32591,
#  'syoummer': 96757,
#  'month': 66368,
#  'child': 22608,
#  'poor': 77031,
#  'wonderfyoul': 116510,
#  'beach': 14954,
#  'appeal': 10751,
#  'site': 90751,
#  'pretty': 78118,
#  'coyourteoyous': 28088,
#  'brekky': 18382,
#  'minibar': 65223,
#  'hardly': 48777,
#  'english': 37083,
#  'scyouff': 87887,
#  'mark': 63267,
#  'look': 61085,
#  'worn': 116790,
#  'overpriced': 72591,
#  'sachet': 86453,
#  'syouggest': 96596,
#  'convenient': 27076,
#  'cryouise': 28791,
#  'port': 77127,
#  'rambla': 80577,
#  'hop': 50826,
#  'awfyoul': 13063,
#  'tiny': 100418,
#  'greeted': 47365,
#  'clerk': 23925,
#  'beayoutifyoully': 15164,
#  'dressed': 34275,
#  'manicyoured': 62887,
#  'older': 71173,
#  'woman': 116481,
#  'recalled': 81278,
#  'efficient': 35911,
#  'youpdated': 119364,
#  'loyounge': 61481,
#  'milk': 65081,
#  'date': 29716,
#  'cyourdled': 29107,
#  'tea': 98166,
#  'liked': 59822,
#  'neighboyourhood': 68418,
#  'smell': 91543,
#  'ver': 112608,
#  'robe': 85091,
#  'slipper': 91256,
#  'awkward': 13081,
#  'lyouxyourioyous': 61997,
#  'came': 20149,
#  '4th': 3902,
#  'visit': 113231,
#  '47': 3737,
#  'yr': 120055,
#  'village': 113088,
#  'girl': 46152,
#  'big': 16336,
#  'nt': 70229,
#  'chosen': 22934,
#  'standing': 94272,
#  'gyouest': 47843,
#  'waiting': 113812,
#  'willing': 115989,
#  'hoyouse': 51561,
#  'familiar': 40828,
#  'tyoub': 102886,
#  'meal': 63989,
#  'byourger': 19389,
#  'standard': 94232,
#  'disgrace': 32756,
#  'honest': 50721,
#  'confirmed': 26286,
#  'store': 95207,
#  'boyought': 17770,
#  'mc': 63885,
#  'cain': 19971,
#  'chip': 22706,
#  'feel': 41504,
#  'relaxed': 82681,
#  'wife': 115852,
#  'dose': 33843,
#  'serve': 88706,
#  'gin': 46112,
#  'spoken': 93437,
#  'cyourtain': 29163,
#  'tram': 101718,
#  'special': 93057,
#  'professional': 78713,
#  'vangelis': 112189,
#  'soyound': 92620,
#  'proofing': 78957,
#  'welcome': 114904,
#  'execyoutive': 39220,
#  'family': 40854,
#  'en': 36850,
#  'chang': 21918,
#  'thirty': 99692,
#  'year': 117376,
#  'ac': 6461,
#  'younits': 118717,
#  'blockmore': 16916,
#  'speedy': 93191,
#  'syouper': 96904,
#  'concierge': 25980,
#  'personable': 75139,
#  'spotless': 93508,
#  'environment': 37530,
#  'shyout': 90112,
#  'cooling': 27277,
#  'fan': 40915,
#  'throw': 99980,
#  'dyouvet': 34955,
#  'wait': 113783,
#  'elevator': 36329,
#  'staffed': 94000,
#  'coyouldn': 27922,
#  'gave': 45432,
#  'recommendation': 81677,
#  'restyourants': 84078,
#  'tyoube': 102891,
#  'overall': 72389,
#  'royound': 85974,
#  'maybe': 63802,
#  '38': 3277,
#  'wash': 114253,
#  'teeth': 98414,
#  'lift': 59706,
#  'awesome': 13030,
#  'coming': 25172,
#  'thats': 99064,
#  'norm': 69783,
#  'allowed': 8831,
#  'weekend': 114782,
#  'break': 18079,
#  'cooky': 27263,
#  'member': 64296,
#  'signed': 90338,
#  'nite': 69243,
#  'wasnt': 114308,
#  'byousy': 19591,
#  'chatting': 22181,
#  'order': 71975,
#  'served': 88709,
#  'arrived': 11641,
#  'reqyouested': 83378,
#  'dated': 29717,
#  'looked': 61090,
#  'booked': 17411,
#  'basis': 14529,
#  'tile': 100227,
#  'crack': 28226,
#  'tlc': 100541,
#  'drawer': 34204,
#  'falling': 40785,
#  'foyour': 43546,
#  'coat': 24375,
#  'hanger': 48617,
#  'wardrobe': 114121,
#  'tidy': 100159,
#  'rain': 80496,
#  'direction': 32326,
#  'website': 114699,
#  'black': 16668,
#  'hairy': 48303,
#  'spider': 93277,
#  'climbing': 23986,
#  'cyourtains': 29169,
#  'spare': 92937,
#  'towel': 101295,
#  've': 112347,
#  'hair': 48260,
#  'brasserie': 17978,
#  'exceptionally': 39049,
#  'arrival': 11619,
#  'delyouxe': 30912,
#  'amoyount': 9604,
#  'checked': 22284,
#  'adjyousting': 7296,
#  'metal': 64592,
#  'drainage': 34160,
#  'blocked': 16910,
#  'end': 36936,
#  'contained': 26839,
#  'started': 94388,
#  'leak': 59042,
#  'pipe': 75898,
#  'younderneath': 118195,
#  'corroding': 27632,
#  'badly': 13710,
#  'nespresso': 68547,
#  'white': 115661,
#  '2017': 2003,
#  'charging': 22075,
#  'wifii': 115886,
#  'kinda': 57490,
#  'lame': 58423,
#  'sea': 87949,
#  'renovated': 83048,
#  'jamon': 55852,
#  'disapponting': 32523,
#  'elevetors': 36361,
#  'yousyoually': 119795,
#  'try': 102544,
#  'brand': 17940,
#  'reward': 84445,
#  'promotion': 78913,
#  'discoyount': 32647,
#  'organization': 72041,
#  'belong': 15700,
#  'recently': 81359,
#  'inn': 53912,
#  'property': 79003,
#  'youpgraded': 119414,
#  'unfortyounately': 111521,
#  'case': 20891,
#  '40': 3458,
#  'brilliant': 18547,
#  'no1': 69311,
#  'preferred': 77808,
#  'list': 60111,
#  'checking': 22300,
#  'wimbledon': 116018,
#  'catered': 21067,
#  'generoyously': 45698,
#  'resyoult': 84102,
#  'able': 6234,
#  'largest': 58645,
#  'roomssyouites': 85706,
#  'syourreal': 97319,
#  'visited': 113247,
#  'friday': 44056,
#  'downside': 33935,
#  'vey': 112831,
#  'december': 30159,
#  'handy': 48600,
#  'art': 11715,
#  'covent': 27829,
#  'carvery': 20868,
#  'hdtv': 49166,
#  '230pm': 2271,
#  'told': 100827,
#  'ready': 80985,
#  '30mins': 2996,
#  'stroll': 95575,
#  'retyourned': 84248,
#  '60mins': 4476,
#  'later': 58728,
#  '45mins': 3702,
#  'chasing': 22148,
#  'process': 78629,
#  'took': 100999,
#  'noticed': 70006,
#  'remote': 82941,
#  'waited': 113790,
#  'mentioned': 64415,
#  'foyourth': 43574,
#  'speak': 93028,
#  'manager': 62722,
#  'charge': 22048,
#  'response': 83737,
#  'prater': 77602,
#  'kid': 57402,
#  'adyoults': 7501,
#  'swipe': 96163,
#  'card': 20550,
#  'worked': 116669,
#  'instantaneoyously': 54208,
#  'lock': 60729,
#  'system': 97484,
#  'responsive': 83750,
#  'impressed': 52902,
#  'styouff': 95795,
#  'qyouietly': 80154,
#  'efficiently': 35925,
#  'bike': 16401,
#  'hire': 50326,
#  'directly': 32347,
#  'pyoubs': 79421,
#  'head': 49180,
#  'wanted': 114082,
#  'remained': 82801,
#  'flop': 42712,
#  'easily': 35420,
#  ...}

# %%
from scipy.sparse import csr_matrix

# Assuming your_sparse_matrix is the sparse matrix you have
# Splitting the matrix into two parts based on row indices
X_train = X[:278435]
X_test = X[278435:]

# %%
X_train = hstack([X_train, df_train.loc[:, 'hotel_rating_mean'].values.reshape(-1, 1)])
X_test = hstack([X_test, df_test.loc[:, 'hotel_rating_mean'].values.reshape(-1, 1)])

# %%
y_train = df_train['review_rating']

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=.2, random_state=42)

# %%
# XGBoost regression model
xg_reg = xgb.XGBRegressor(objective ='reg:squarederror', colsample_bytree = 0.3, learning_rate = 0.1,
                max_depth = 5, alpha = 10, n_estimators = 100)

# %%
xg_reg.fit(X_train, y_train)
# Out:
# XGBRegressor(alpha=10, base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.3, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, ...)

# %%
pred = xg_reg.predict(X_valid)

# %%
# Evaluating the model
rmse = mean_squared_error(y_valid, pred, squared=False)
print("Root Mean Squared Error:", rmse)
# Out:
# Root Mean Squared Error: 1.2392319084709522

# %%
pred_test = xg_reg.predict(X_test)

# %%
submission = pd.DataFrame()
submission['review_id'] = df_test['review_id']
submission['review_rating'] = pred_test

submission.head()
# Out:
#           review_id  review_rating
# 0  9p62eIN5NkEadRe7       8.031348
# 1  WfQozacJ1lzXMFQg       9.167491
# 2  oahzyhSR3ZNHJBuI       9.076857
# 3  lcO2pUMVQ09RmbHZ       6.949605
# 4  DmMu1z2SozPxykUS       8.801266

# %%
submission.to_csv(r'submission/submission_6.csv', index=False)
